# %% [markdown]
# <a href="https://colab.research.google.com/github/parismita0528/18cse086_dmdw/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
path="https://raw.githubusercontent.com/parismita0528/18cse086_dmdw/main/Toyota.csv"
data =pd.read_csv(path)
data
# Out:
#       Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0              0  13500  23.0  46986  ...         0  2000  three    1165
# 1              1  13750  23.0  72937  ...         0  2000      3    1165
# 2              2  13950  24.0  41711  ...         0  2000      3    1165
# 3              3  14950  26.0  48000  ...         0  2000      3    1165
# 4              4  13750  30.0  38500  ...         0  2000      3    1170
# ...          ...    ...   ...    ...  ...       ...   ...    ...     ...
# 1431        1431   7500   NaN  20544  ...         0  1300      3    1025
# 1432        1432  10845  72.0     ??  ...         0  1300      3    1015
# 1433        1433   8500   NaN  17016  ...         0  1300      3    1015
# 1434        1434   7250  70.0     ??  ...         0  1300      3    1015
# 1435        1435   6950  76.0      1  ...         0  1600      5    1114
#
# [1436 rows x 11 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (1436, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1336 non-null   float64
#  3   KM          1436 non-null   object
#  4   FuelType    1336 non-null   object
#  5   HP          1436 non-null   object
#  6   MetColor    1286 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   object
#  10  Weight      1436 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 123.5+ KB

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1436, step=1)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor',
#        'Automatic', 'CC', 'Doors', 'Weight'],
#       dtype='object')

# %%
data.head()
# Out:
#    Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0           0  13500  23.0  46986  ...         0  2000  three    1165
# 1           1  13750  23.0  72937  ...         0  2000      3    1165
# 2           2  13950  24.0  41711  ...         0  2000      3    1165
# 3           3  14950  26.0  48000  ...         0  2000      3    1165
# 4           4  13750  30.0  38500  ...         0  2000      3    1170
#
# [5 rows x 11 columns]

# %%
data.tail()
# Out:
#       Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 1431        1431   7500   NaN  20544  ...         0  1300      3    1025
# 1432        1432  10845  72.0     ??  ...         0  1300      3    1015
# 1433        1433   8500   NaN  17016  ...         0  1300      3    1015
# 1434        1434   7250  70.0     ??  ...         0  1300      3    1015
# 1435        1435   6950  76.0      1  ...         0  1600      5    1114
#
# [5 rows x 11 columns]

# %%
data.head(5)
# Out:
#    Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0           0  13500  23.0  46986  ...         0  2000  three    1165
# 1           1  13750  23.0  72937  ...         0  2000      3    1165
# 2           2  13950  24.0  41711  ...         0  2000      3    1165
# 3           3  14950  26.0  48000  ...         0  2000      3    1165
# 4           4  13750  30.0  38500  ...         0  2000      3    1170
#
# [5 rows x 11 columns]

# %%
data[['Price',"Age"]].head(10)
# Out:
#    Price   Age
# 0  13500  23.0
# 1  13750  23.0
# 2  13950  24.0
# 3  14950  26.0
# 4  13750  30.0
# 5  12950  32.0
# 6  16900  27.0
# 7  18600  30.0
# 8  21500  27.0
# 9  12950  23.0

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Age           100
# KM              0
# FuelType      100
# HP              0
# MetColor      150
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# dtype: int64

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# Unnamed: 0    0
# Price         0
# Age           0
# KM            0
# FuelType      0
# HP            0
# MetColor      0
# Automatic     0
# CC            0
# Doors         0
# Weight        0
# dtype: int64

# %%
data.shape
# Out:
# (1111, 11)

# %%
data.head(10)
# Out:
#     Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0            0  13500  23.0  46986  ...         0  2000  three    1165
# 1            1  13750  23.0  72937  ...         0  2000      3    1165
# 3            3  14950  26.0  48000  ...         0  2000      3    1165
# 4            4  13750  30.0  38500  ...         0  2000      3    1170
# 5            5  12950  32.0  61000  ...         0  2000      3    1170
# 8            8  21500  27.0  19700  ...         0  1800      3    1185
# 10          10  20950  25.0  31461  ...         0  1800      3    1185
# 11          11  19950  22.0  43610  ...         0  1800      3    1185
# 12          12  19600  25.0  32189  ...         0  1800      3    1185
# 13          13  21500  31.0  23000  ...         0  1800      3    1185
#
# [10 rows x 11 columns]

# %%
data['MetColor'].mean()
# Out:
# 0.6750675067506751

# %%
data['MetColor'].head()
# Out:
# 0    1.0
# 1    1.0
# 3    0.0
# 4    0.0
# 5    0.0
# Name: MetColor, dtype: float64

# %%
import numpy as np
data['MetColor'].replace(np.NaN,data['MetColor'].mean()).head()
# Out:
# 0    1.0
# 1    1.0
# 3    0.0
# 4    0.0
# 5    0.0
# Name: MetColor, dtype: float64

# %%
data.head(10)
# Out:
#     Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0            0  13500  23.0  46986  ...         0  2000  three    1165
# 1            1  13750  23.0  72937  ...         0  2000      3    1165
# 3            3  14950  26.0  48000  ...         0  2000      3    1165
# 4            4  13750  30.0  38500  ...         0  2000      3    1170
# 5            5  12950  32.0  61000  ...         0  2000      3    1170
# 8            8  21500  27.0  19700  ...         0  1800      3    1185
# 10          10  20950  25.0  31461  ...         0  1800      3    1185
# 11          11  19950  22.0  43610  ...         0  1800      3    1185
# 12          12  19600  25.0  32189  ...         0  1800      3    1185
# 13          13  21500  31.0  23000  ...         0  1800      3    1185
#
# [10 rows x 11 columns]

# %%
data['CC'].mean()
# Out:
# 1569.4635463546354

# %%
data['CC'].head()
# Out:
# 0    2000
# 1    2000
# 3    2000
# 4    2000
# 5    2000
# Name: CC, dtype: int64

# %%
data[['Age',"KM"]].head(20)
# Out:
#      Age     KM
# 0   23.0  46986
# 1   23.0  72937
# 3   26.0  48000
# 4   30.0  38500
# 5   32.0  61000
# 8   27.0  19700
# 10  25.0  31461
# 11  22.0  43610
# 12  25.0  32189
# 13  31.0  23000
# 14  32.0  34131
# 15  28.0  18739
# 16  30.0  34000
# 17  24.0  21716
# 18  24.0  25563
# 19  30.0  64359
# 20  30.0  67660
# 22  28.0  56349
# 23  28.0  32220
# 24  29.0  25813
